# %% [markdown]
# # Titanic Worked Example
# Author: Andrew Szwec

# %% [markdown]
# <img src="./images/titanic.jpg" alt="Titanic" width=400 height=600>

# %% [markdown]
# <img src="./images/titanic_voyage.jpg" alt="Voyage" width=800>

# %% [markdown]
# ## Hypothesis
#
# **In the Titanic passenger dataset downloaded from https://github.com/generalassembly-studio/dat10syd/tree/master/data, containing data from 2/4/1912 to 14/4/1912, passengers in 1st class (Pclass==1) have a higher likelihood of survival than passengers in 3rd class (Pclass==3).**
#
# <img src="./images/smart.png" alt="Smart" width=600>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from string import ascii_letters
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp','Parch', 'Fare', 'Embarked']]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  22.0      1      0    7.2500        S
# 1           1       1  female  38.0      1      0   71.2833        C
# 2           1       3  female  26.0      0      0    7.9250        S
# 3           1       1  female  35.0      1      0   53.1000        S
# 4           0       3    male  35.0      0      0    8.0500        S
# 5           0       3    male   NaN      0      0    8.4583        Q
# 6           0       1    male  54.0      0      0   51.8625        S
# 7           0       3    male   2.0      3      1   21.0750        S
# 8           1       3  female  27.0      0      2   11.1333        S
# 9           1       2  female  14.0      1      0   30.0708        C
# 10          1       3  female   4.0      1      1   16.7000        S
# 11          1       1  female  58.0      0      0   26.5500        S
# 12          0       3    male  20.0      0      0    8.0500        S
# 13          0       3    male  39.0      1      5   31.2750        S
# 14          0       3  female  14.0      0      0    7.8542        S
# 15          1       2  female  55.0      0      0   16.0000        S
# 16          0       3    male   2.0      4      1   29.1250        Q
# 17          1       2    male   NaN      0      0   13.0000        S
# 18          0       3  female  31.0      1      0   18.0000        S
# 19          1       3  female   NaN      0      0    7.2250        C
# 20          0       2    male  35.0      0      0   26.0000        S
# 21          1       2    male  34.0      0      0   13.0000        S
# 22          1       3  female  15.0      0      0    8.0292        Q
# 23          1       1    male  28.0      0      0   35.5000        S
# 24          0       3  female   8.0      3      1   21.0750        S
# 25          1       3  female  38.0      1      5   31.3875        S
# 26          0       3    male   NaN      0      0    7.2250        C
# 27          0       1    male  19.0      3      2  263.0000        S
# 28          1       3  female   NaN      0      0    7.8792        Q
# 29          0       3    male   NaN      0      0    7.8958        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 861         0       2    male  21.0      1      0   11.5000        S
# 862         1       1  female  48.0      0      0   25.9292        S
# 863         0       3  female   NaN      8      2   69.5500        S
# 864         0       2    male  24.0      0      0   13.0000        S
# 865         1       2  female  42.0      0      0   13.0000        S
# 866         1       2  female  27.0      1      0   13.8583        C
# 867         0       1    male  31.0      0      0   50.4958        S
# 868         0       3    male   NaN      0      0    9.5000        S
# 869         1       3    male   4.0      1      1   11.1333        S
# 870         0       3    male  26.0      0      0    7.8958        S
# 871         1       1  female  47.0      1      1   52.5542        S
# 872         0       1    male  33.0      0      0    5.0000        S
# 873         0       3    male  47.0      0      0    9.0000        S
# 874         1       2  female  28.0      1      0   24.0000        C
# 875         1       3  female  15.0      0      0    7.2250        C
# 876         0       3    male  20.0      0      0    9.8458        S
# 877         0       3    male  19.0      0      0    7.8958        S
# 878         0       3    male   NaN      0      0    7.8958        S
# 879         1       1  female  56.0      0      1   83.1583        C
# 880         1       2  female  25.0      0      1   26.0000        S
# 881         0       3    male  33.0      0      0    7.8958        S
# 882         0       3  female  22.0      0      0   10.5167        S
# 883         0       2    male  28.0      0      0   10.5000        S
# 884         0       3    male  25.0      0      0    7.0500        S
# 885         0       3  female  39.0      0      5   29.1250        Q
# 886         0       2    male  27.0      0      0   13.0000        S
# 887         1       1  female  19.0      0      0   30.0000        S
# 888         0       3  female   NaN      1      2   23.4500        S
# 889         1       1    male  26.0      0      0   30.0000        C
# 890         0       3    male  32.0      0      0    7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ## Count of Survived by passenger class

# %%
df.groupby(['Pclass', 'Survived']).count()
# Out:
#                  PassengerId  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived
# 1      0                  80    80   80   64     80     80      80    80
#        1                 136   136  136  122    136    136     136   136
# 2      0                  97    97   97   90     97     97      97    97
#        1                  87    87   87   83     87     87      87    87
# 3      0                 372   372  372  270    372    372     372   372
#        1                 119   119  119   85    119    119     119   119
#
#                  Cabin  Embarked
# Pclass Survived
# 1      0            59        80
#        1           117       134
# 2      0             3        97
#        1            13        87
# 3      0             6       372
#        1             6       119

# %%
def myfunc(x):
    print(x)
    

myfunc('hello world')
# Out:
# hello world

# %%
# Using Function
def survived_name(x):
    if x == 0:
        return 'Perished'
    else:
        return 'Survived'
    
survived_name('string')
# Out:
# 'Survived'

# %%
# Using Dictionary
class_dict = {1: '1st', 2: '2nd', 3: '3rd'}
    
df['SurvivedDesc'] = df['Survived'].apply(survived_name)
df['PclassDesc'] = df['Pclass'].apply(class_dict.get)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked SurvivedDesc PclassDesc
# 0      0         A/5 21171   7.2500   NaN        S     Perished        3rd
# 1      0          PC 17599  71.2833   C85        C     Survived        1st
# 2      0  STON/O2. 3101282   7.9250   NaN        S     Survived        3rd
# 3      0            113803  53.1000  C123        S     Survived        1st
# 4      0            373450   8.0500   NaN        S     Perished        3rd

# %%
df.groupby(['PclassDesc', 'SurvivedDesc']).count()['PassengerId'] \
    .plot(kind='bar', stacked=True, title='Count Survived by Pclass' \
          , legend=True, fontsize=15, colormap='spring')

# %% [markdown]
# This does not prove that you were more likely to survive in 3rd class. It just shows there were more people in 3rd class that did survive, but what were the volume of 3rd class passengers compared to 1st class?

# %%
# Percent by Volume
grp_class_surv = df.groupby(['PclassDesc', 'SurvivedDesc']).agg({'PassengerId': 'count'})
print(grp_class_surv)

# Calculate Percentage
grp_perc = grp_class_surv.groupby(level=0).apply(lambda x:  x / float(x.sum()) * 100)
# Print table
print(grp_perc)

ax = grp_perc.plot(kind='bar', stacked=True, title='Percent Survived by Pclass', legend=True, fontsize=15, colormap='autumn')

for p in ax.patches:
    ax.annotate(str(np.round(p.get_height(),0))+'%', (p.get_x() * 1.005, p.get_height() * 1.005))
# Out:
#                          PassengerId
# PclassDesc SurvivedDesc
# 1st        Perished               80
#            Survived              136
# 2nd        Perished               97
#            Survived               87
# 3rd        Perished              372
#            Survived              119
#                          PassengerId
# PclassDesc SurvivedDesc
# 1st        Perished        37.037037
#            Survived        62.962963
# 2nd        Perished        52.717391
#            Survived        47.282609
# 3rd        Perished        75.763747
#            Survived        24.236253

# %%
grp_perc.index
# Out:
# MultiIndex(levels=[['1st', '2nd', '3rd'], ['Perished', 'Survived']],
#            labels=[[0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1]],
#            names=['PclassDesc', 'SurvivedDesc'])

# %% [markdown]
# # Lets look at Survived only

# %%
# Percent by Volume
grp_class_surv = df.groupby(['PclassDesc', 'SurvivedDesc']).agg({'PassengerId': 'count'})
# Calculate Percentage
grp_perc = grp_class_surv.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))


ax = grp_perc.plot(kind='bar', stacked=True, title='Percent Survived by Pclass', legend=True, fontsize=15, colormap='autumn')

for p in ax.patches:
    ax.annotate(str(np.round(p.get_height(),0))+'%', (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
a = grp_perc.reset_index()[grp_perc.reset_index().SurvivedDesc == 'Survived'].set_index(['PclassDesc', 'SurvivedDesc'])

ax = a.plot(kind='bar', stacked=True, title='Percent Survived by Pclass', legend=True, fontsize=15, colormap='autumn')

for p in ax.patches:
    ax.annotate(str(np.round(p.get_height(),0))+'%', (p.get_x() * 1.005, p.get_height() * 1.005))

# %% [markdown]
# ## Conclusion
# After analysising the Titanic dataset the hypothesis has been proven true. The above figure shows that the likelihood of survival for a 1st class passenger is 63%, while the likelihood of a 3rd class passenger is 24%.

# %% [markdown]
# ## Lets Explore this dataset further

# %%
grp = df.groupby('Sex').count()['Survived'].reset_index()
grp
# Out:
#       Sex  Survived
# 0  female       314
# 1    male       577

# %% [markdown]
# ## Pandas Plotting Cookbook
# ### Charts
# https://pandas.pydata.org/pandas-docs/stable/visualization.html
# ### Plotting Options
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
# ## Colour Maps
# https://matplotlib.org/users/colormaps.html

# %%
grp.set_index('Sex').plot.bar(title='Count of Survived', legend=True, fontsize=15, colormap='summer')

# %%
grp = df.groupby(['Sex', 'Pclass']).count()['Survived'].reset_index()
grp
# Out:
#       Sex  Pclass  Survived
# 0  female       1        94
# 1  female       2        76
# 2  female       3       144
# 3    male       1       122
# 4    male       2       108
# 5    male       3       347

# %%
df['Fare'].plot.hist(alpha=0.5, title='Distribution of Fare', legend=True, fontsize=15, colormap='winter')

# %%
df['Age'].plot.box( title='Distribution of Age', legend=True, fontsize=15, colormap='viridis')

# %%
df.groupby('Sex').mean()['Age'].plot(kind='bar', title='Mean of Age by Gender', legend=True, fontsize=15, colormap='viridis')

# %%
df.groupby('Pclass').mean()['Age'].plot(kind='bar', title='Mean Age by Passenger Class', legend=True, fontsize=15, colormap='summer')

# %%
df.groupby('SibSp').count()['Survived'].plot(kind='bar', title='Count Survived by Number Siblings/Spouse', legend=True, fontsize=15, colormap='inferno')

# %% [markdown]
# ## Subset to the useful columns

# %%
dd = df[['Survived', 'SibSp', 'Pclass', 'Sex', 'Age', 'Parch', 'Fare', 'Embarked']]
dd.head()
# Out:
#    Survived  SibSp  Pclass     Sex   Age  Parch     Fare Embarked
# 0         0      1       3    male  22.0      0   7.2500        S
# 1         1      1       1  female  38.0      0  71.2833        C
# 2         1      0       3  female  26.0      0   7.9250        S
# 3         1      1       1  female  35.0      0  53.1000        S
# 4         0      0       3    male  35.0      0   8.0500        S

# %% [markdown]
# ## Correlation of key variables and Target

# %%
sns.set(style="white")

# Compute the correlation matrix
corr = dd.corr()

corr
# Out:
#           Survived     SibSp    Pclass       Age     Parch      Fare
# 880         1      0       2  25.0      1   26.0000           1         0
# 881         0      0       3  33.0      0    7.8958           0         1
# 882         0      0       3  22.0      0   10.5167           1         0
# 883         0      0       2  28.0      0   10.5000           0         1
# 884         0      0       3  25.0      0    7.0500           0         1
# 885         0      0       3  39.0      5   29.1250           1         0
# 886         0      0       2  27.0      0   13.0000           0         1
# 887         1      0       1  19.0      0   30.0000           1         0
# 888         0      1       3   NaN      2   23.4500           1         0
# 889         1      0       1  26.0      0   30.0000           0         1
# 890         0      0       3  32.0      0    7.7500           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# 5             0           1           0
# 6             0           0           1
# 7             0           0           1
# 8             0           0           1
# 9             1           0           0
# 10            0           0           1
# 11            0           0           1
# 12            0           0           1
# 13            0           0           1
# 14            0           0           1
# 15            0           0           1
# 16            0           1           0
# 17            0           0           1
# 18            0           0           1
# 19            1           0           0
# 20            0           0           1
# 21            0           0           1
# 22            0           1           0
# 23            0           0           1
# 24            0           0           1
# 25            0           0           1
# 26            1           0           0
# 27            0           0           1
# 28            0           1           0
# 29            0           0           1
# ..          ...         ...         ...
# 861           0           0           1
# 862           0           0           1
# 863           0           0           1
# 864           0           0           1
# 865           0           0           1
# 866           1           0           0
# 867           0           0           1
# 868           0           0           1
# 869           0           0           1
# 870           0           0           1
# 871           0           0           1
# 872           0           0           1
# 873           0           0           1
# 874           1           0           0
# 875           1           0           0
# 876           0           0           1
# 877           0           0           1
# 878           0           0           1
# 879           1           0           0
# 880           0           0           1
# 881           0           0           1
# 882           0           0           1
# 883           0           0           1
# 884           0           0           1
# 885           0           1           0
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [891 rows x 11 columns]

# %% [markdown]
# ## Remove Missing Records

# %%
dd_dum.dropna(axis=0, how='any', thresh=None, subset=None, inplace=True)

# %% [markdown]
# ## Train Test Split

# %%
# ?RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
seed = 1234

x = dd_dum.drop('Survived', axis=1)
y = dd_dum['Survived']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=seed)

# %%
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
# link http://scikit-learn.org/stable/auto_examples/ensemble/plot_feature_transformation.html#sphx-glr-auto-examples-ensemble-plot-feature-transformation-py
n_estimator = 20

rf = RandomForestClassifier( max_depth=3, n_estimators=10)
rf.fit(x_train, y_train)
print('The mean accuracy: {}'.format( np.round(rf.score(x_test, y_test), 3) ))
# Out:
# The mean accuracy: 0.694

# %% [markdown]
# ## Find the best model with a grid search

# %%
acc = []
log = []
i = 0
for est in range(6, 13):
    for depth in range(2,10):
        rf = RandomForestClassifier(max_depth=depth, n_estimators=est)
        rf.fit(x_train, y_train)
        scr = rf.score(x_test, y_test)
        details = 'Model {}, n_estimators={}, max-depth={} The mean accuracy={}'.format( i, est, depth, np.round(scr, 3) )
        print(details)
        acc.append(scr)
        log.append(details)
        # iterate
        i += 1
# Out:
# Model 0, n_estimators=6, max-depth=2 The mean accuracy=0.694
# Model 1, n_estimators=6, max-depth=3 The mean accuracy=0.736
# Model 2, n_estimators=6, max-depth=4 The mean accuracy=0.708
# Model 3, n_estimators=6, max-depth=5 The mean accuracy=0.764
# Model 4, n_estimators=6, max-depth=6 The mean accuracy=0.764
# Model 5, n_estimators=6, max-depth=7 The mean accuracy=0.778
# Model 6, n_estimators=6, max-depth=8 The mean accuracy=0.736
# Model 7, n_estimators=6, max-depth=9 The mean accuracy=0.764
# Model 8, n_estimators=7, max-depth=2 The mean accuracy=0.778
# Model 9, n_estimators=7, max-depth=3 The mean accuracy=0.722
# Model 10, n_estimators=7, max-depth=4 The mean accuracy=0.792
# Model 11, n_estimators=7, max-depth=5 The mean accuracy=0.792
# Model 12, n_estimators=7, max-depth=6 The mean accuracy=0.778
# Model 13, n_estimators=7, max-depth=7 The mean accuracy=0.736
# Model 14, n_estimators=7, max-depth=8 The mean accuracy=0.764
# Model 15, n_estimators=7, max-depth=9 The mean accuracy=0.792
# Model 16, n_estimators=8, max-depth=2 The mean accuracy=0.708
# Model 17, n_estimators=8, max-depth=3 The mean accuracy=0.694
# Model 18, n_estimators=8, max-depth=4 The mean accuracy=0.792
# Model 19, n_estimators=8, max-depth=5 The mean accuracy=0.792
# Model 20, n_estimators=8, max-depth=6 The mean accuracy=0.764
# Model 21, n_estimators=8, max-depth=7 The mean accuracy=0.792
# Model 22, n_estimators=8, max-depth=8 The mean accuracy=0.75
# Model 23, n_estimators=8, max-depth=9 The mean accuracy=0.75
# Model 24, n_estimators=9, max-depth=2 The mean accuracy=0.819
# Model 25, n_estimators=9, max-depth=3 The mean accuracy=0.694
# Model 26, n_estimators=9, max-depth=4 The mean accuracy=0.778
# Model 27, n_estimators=9, max-depth=5 The mean accuracy=0.75
# Model 28, n_estimators=9, max-depth=6 The mean accuracy=0.736
# Model 29, n_estimators=9, max-depth=7 The mean accuracy=0.75
# Model 30, n_estimators=9, max-depth=8 The mean accuracy=0.764
# Model 31, n_estimators=9, max-depth=9 The mean accuracy=0.736
# Model 32, n_estimators=10, max-depth=2 The mean accuracy=0.694
# Model 33, n_estimators=10, max-depth=3 The mean accuracy=0.694
# Model 34, n_estimators=10, max-depth=4 The mean accuracy=0.764
# Model 35, n_estimators=10, max-depth=5 The mean accuracy=0.764
# Model 36, n_estimators=10, max-depth=6 The mean accuracy=0.778
# Model 37, n_estimators=10, max-depth=7 The mean accuracy=0.806
# Model 38, n_estimators=10, max-depth=8 The mean accuracy=0.778
# Model 39, n_estimators=10, max-depth=9 The mean accuracy=0.778
# Model 40, n_estimators=11, max-depth=2 The mean accuracy=0.694
# Model 41, n_estimators=11, max-depth=3 The mean accuracy=0.722
# Model 42, n_estimators=11, max-depth=4 The mean accuracy=0.764
# Model 43, n_estimators=11, max-depth=5 The mean accuracy=0.806
# Model 44, n_estimators=11, max-depth=6 The mean accuracy=0.764
# Model 45, n_estimators=11, max-depth=7 The mean accuracy=0.806
# Model 46, n_estimators=11, max-depth=8 The mean accuracy=0.778
# Model 47, n_estimators=11, max-depth=9 The mean accuracy=0.847
# Model 48, n_estimators=12, max-depth=2 The mean accuracy=0.694
# Model 49, n_estimators=12, max-depth=3 The mean accuracy=0.75
# Model 50, n_estimators=12, max-depth=4 The mean accuracy=0.722
# Model 51, n_estimators=12, max-depth=5 The mean accuracy=0.792
# Model 52, n_estimators=12, max-depth=6 The mean accuracy=0.764
# Model 53, n_estimators=12, max-depth=7 The mean accuracy=0.764
# Model 54, n_estimators=12, max-depth=8 The mean accuracy=0.764
# Model 55, n_estimators=12, max-depth=9 The mean accuracy=0.778

# %% [markdown]
# ## Best Model

# %%
log[np.argmax(acc)]
# Out:
# 'Model 47, n_estimators=11, max-depth=9 The mean accuracy=0.847'

# %%
n_estimator = 20
depth=10

rf = RandomForestClassifier(max_depth=depth, n_estimators=n_estimator)
rf.fit(x_train, y_train)
print('The mean accuracy: {}'.format( np.round(rf.score(x_test, y_test), 3) ))

# %%
preds = rf.predict(x)
preds[0:10]

# %%
dd_dum['preds'] = preds

# %%
dd_dum

# %%
preds = rf.predict_proba(x)
preds2 = [p[1] for p in preds]

# %%
dd_dum['probs'] = preds2
dd_dum

# %% [markdown]
# ## Gradient Boosted Machine

# %%
from sklearn.ensemble import GradientBoostingClassifier

n_estimator = 30

rf = GradientBoostingClassifier(n_estimators=n_estimator)
rf.fit(x_train, y_train)
print('The mean accuracy: {}'.format( np.round(rf.score(x_test, y_test), 3) ))
# Out:
# The mean accuracy: 0.792

# %% [markdown]
# ## Find the best model with a grid search

# %%
acc = []
log = []
i = 0
for est in range(10, 20):
    for depth in range(5,10):
        for lr in np.arange(0.01, 0.1, 0.02):
            rf = GradientBoostingClassifier(max_depth=depth, n_estimators=est, learning_rate=lr)
            rf.fit(x_train, y_train)
            scr = rf.score(x_test, y_test)
            details = 'Model {}, n_estimators={}, max-depth={}, learning_rate={}, The mean accuracy={}'.format( i, est, depth, lr, np.round(scr, 3) )
            print(details)
            acc.append(scr)
            log.append(details)
            # iterate
            i += 1
# Out:
# Model 0, n_estimators=10, max-depth=5, learning_rate=0.01, The mean accuracy=0.611
# Model 1, n_estimators=10, max-depth=5, learning_rate=0.03, The mean accuracy=0.75
# Model 2, n_estimators=10, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.778
# Model 3, n_estimators=10, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.792
# Model 4, n_estimators=10, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.792
# Model 5, n_estimators=10, max-depth=6, learning_rate=0.01, The mean accuracy=0.611
# Model 6, n_estimators=10, max-depth=6, learning_rate=0.03, The mean accuracy=0.778
# Model 7, n_estimators=10, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 8, n_estimators=10, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 9, n_estimators=10, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 10, n_estimators=10, max-depth=7, learning_rate=0.01, The mean accuracy=0.611
# Model 11, n_estimators=10, max-depth=7, learning_rate=0.03, The mean accuracy=0.778
# Model 12, n_estimators=10, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 13, n_estimators=10, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 14, n_estimators=10, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 15, n_estimators=10, max-depth=8, learning_rate=0.01, The mean accuracy=0.611
# Model 16, n_estimators=10, max-depth=8, learning_rate=0.03, The mean accuracy=0.75
# Model 17, n_estimators=10, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 18, n_estimators=10, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 19, n_estimators=10, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 20, n_estimators=10, max-depth=9, learning_rate=0.01, The mean accuracy=0.611
# Model 21, n_estimators=10, max-depth=9, learning_rate=0.03, The mean accuracy=0.75
# Model 22, n_estimators=10, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.722
# Model 23, n_estimators=10, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 24, n_estimators=10, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 25, n_estimators=11, max-depth=5, learning_rate=0.01, The mean accuracy=0.611
# Model 26, n_estimators=11, max-depth=5, learning_rate=0.03, The mean accuracy=0.778
# Model 27, n_estimators=11, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.778
# Model 28, n_estimators=11, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.806
# Model 29, n_estimators=11, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.792
# Model 30, n_estimators=11, max-depth=6, learning_rate=0.01, The mean accuracy=0.611
# Model 31, n_estimators=11, max-depth=6, learning_rate=0.03, The mean accuracy=0.778
# Model 32, n_estimators=11, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 33, n_estimators=11, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 34, n_estimators=11, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.722
# Model 35, n_estimators=11, max-depth=7, learning_rate=0.01, The mean accuracy=0.611
# Model 36, n_estimators=11, max-depth=7, learning_rate=0.03, The mean accuracy=0.778
# Model 37, n_estimators=11, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 38, n_estimators=11, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 39, n_estimators=11, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 40, n_estimators=11, max-depth=8, learning_rate=0.01, The mean accuracy=0.611
# Model 41, n_estimators=11, max-depth=8, learning_rate=0.03, The mean accuracy=0.75
# Model 42, n_estimators=11, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 43, n_estimators=11, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model
max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 133, n_estimators=15, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.764
# Model 134, n_estimators=15, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 135, n_estimators=15, max-depth=7, learning_rate=0.01, The mean accuracy=0.611
# Model 136, n_estimators=15, max-depth=7, learning_rate=0.03, The mean accuracy=0.75
# Model 137, n_estimators=15, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 138, n_estimators=15, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 139, n_estimators=15, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 140, n_estimators=15, max-depth=8, learning_rate=0.01, The mean accuracy=0.611
# Model 141, n_estimators=15, max-depth=8, learning_rate=0.03, The mean accuracy=0.764
# Model 142, n_estimators=15, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 143, n_estimators=15, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 144, n_estimators=15, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 145, n_estimators=15, max-depth=9, learning_rate=0.01, The mean accuracy=0.611
# Model 146, n_estimators=15, max-depth=9, learning_rate=0.03, The mean accuracy=0.736
# Model 147, n_estimators=15, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 148, n_estimators=15, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 149, n_estimators=15, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 150, n_estimators=16, max-depth=5, learning_rate=0.01, The mean accuracy=0.611
# Model 151, n_estimators=16, max-depth=5, learning_rate=0.03, The mean accuracy=0.778
# Model 152, n_estimators=16, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.806
# Model 153, n_estimators=16, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.792
# Model 154, n_estimators=16, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.792
# Model 155, n_estimators=16, max-depth=6, learning_rate=0.01, The mean accuracy=0.611
# Model 156, n_estimators=16, max-depth=6, learning_rate=0.03, The mean accuracy=0.75
# Model 157, n_estimators=16, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 158, n_estimators=16, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.764
# Model 159, n_estimators=16, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 160, n_estimators=16, max-depth=7, learning_rate=0.01, The mean accuracy=0.611
# Model 161, n_estimators=16, max-depth=7, learning_rate=0.03, The mean accuracy=0.75
# Model 162, n_estimators=16, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 163, n_estimators=16, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 164, n_estimators=16, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 165, n_estimators=16, max-depth=8, learning_rate=0.01, The mean accuracy=0.611
# Model 166, n_estimators=16, max-depth=8, learning_rate=0.03, The mean accuracy=0.764
# Model 167, n_estimators=16, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 168, n_estimators=16, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 169, n_estimators=16, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 170, n_estimators=16, max-depth=9, learning_rate=0.01, The mean accuracy=0.611
# Model 171, n_estimators=16, max-depth=9, learning_rate=0.03, The mean accuracy=0.75
# Model 172, n_estimators=16, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 173, n_estimators=16, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 174, n_estimators=16, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.778
# Model 175, n_estimators=17, max-depth=5, learning_rate=0.01, The mean accuracy=0.736
# Model 176, n_estimators=17, max-depth=5, learning_rate=0.03, The mean accuracy=0.778
# Model 177, n_estimators=17, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.806
# Model 178, n_estimators=17, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.792
# Model 179, n_estimators=17, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.764
# Model 180, n_estimators=17, max-depth=6, learning_rate=0.01, The mean accuracy=0.75
# Model 181, n_estimators=17, max-depth=6, learning_rate=0.03, The mean accuracy=0.764
# Model 182, n_estimators=17, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 183, n_estimators=17, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 184, n_estimators=17, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 185, n_estimators=17, max-depth=7, learning_rate=0.01, The mean accuracy=0.764
# Model 186, n_estimators=17, max-depth=7, learning_rate=0.03, The mean accuracy=0.75
# Model 187, n_estimators=17, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 188, n_estimators=17, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 189, n_estimators=17, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 190, n_estimators=17, max-depth=8, learning_rate=0.01, The mean accuracy=0.764
# Model 191, n_estimators=17, max-depth=8, learning_rate=0.03, The mean accuracy=0.778
# Model 192, n_estimators=17, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 193, n_estimators=17, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 194, n_estimators=17, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 195, n_estimators=17, max-depth=9, learning_rate=0.01, The mean accuracy=0.75
# Model 196, n_estimators=17, max-depth=9, learning_rate=0.03, The mean accuracy=0.736
# Model 197, n_estimators=17, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 198, n_estimators=17, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 199, n_estimators=17, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 200, n_estimators=18, max-depth=5, learning_rate=0.01, The mean accuracy=0.736
# Model 201, n_estimators=18, max-depth=5, learning_rate=0.03, The mean accuracy=0.778
# Model 202, n_estimators=18, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.806
# Model 203, n_estimators=18, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.806
# Model 204, n_estimators=18, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.778
# Model 205, n_estimators=18, max-depth=6, learning_rate=0.01, The mean accuracy=0.75
# Model 206, n_estimators=18, max-depth=6, learning_rate=0.03, The mean accuracy=0.764
# Model 207, n_estimators=18, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 208, n_estimators=18, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.764
# Model 209, n_estimators=18, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 210, n_estimators=18, max-depth=7, learning_rate=0.01, The mean accuracy=0.764
# Model 211, n_estimators=18, max-depth=7, learning_rate=0.03, The mean accuracy=0.75
# Model 212, n_estimators=18, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 213, n_estimators=18, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.722
# Model 214, n_estimators=18, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.708
# Model 215, n_estimators=18, max-depth=8, learning_rate=0.01, The mean accuracy=0.764
# Model 216, n_estimators=18, max-depth=8, learning_rate=0.03, The mean accuracy=0.75
# Model 217, n_estimators=18, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.764
# Model 218, n_estimators=18, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.722
# Model 219, n_estimators=18, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 220, n_estimators=18, max-depth=9, learning_rate=0.01, The mean accuracy=0.75
# Model 221, n_estimators=18, max-depth=9, learning_rate=0.03, The mean accuracy=0.736
# Model 222, n_estimators=18, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 223, n_estimators=18, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 224, n_estimators=18, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 225, n_estimators=19, max-depth=5, learning_rate=0.01, The mean accuracy=0.736
# Model 226, n_estimators=19, max-depth=5, learning_rate=0.03, The mean accuracy=0.778
# Model 227, n_estimators=19, max-depth=5, learning_rate=0.049999999999999996, The mean accuracy=0.806
# Model 228, n_estimators=19, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.806
# Model 229, n_estimators=19, max-depth=5, learning_rate=0.08999999999999998, The mean accuracy=0.778
# Model 230, n_estimators=19, max-depth=6, learning_rate=0.01, The mean accuracy=0.75
# Model 231, n_estimators=19, max-depth=6, learning_rate=0.03, The mean accuracy=0.764
# Model 232, n_estimators=19, max-depth=6, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 233, n_estimators=19, max-depth=6, learning_rate=0.06999999999999999, The mean accuracy=0.764
# Model 234, n_estimators=19, max-depth=6, learning_rate=0.08999999999999998, The mean accuracy=0.736
# Model 235, n_estimators=19, max-depth=7, learning_rate=0.01, The mean accuracy=0.764
# Model 236, n_estimators=19, max-depth=7, learning_rate=0.03, The mean accuracy=0.75
# Model 237, n_estimators=19, max-depth=7, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 238, n_estimators=19, max-depth=7, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 239, n_estimators=19, max-depth=7, learning_rate=0.08999999999999998, The mean accuracy=0.722
# Model 240, n_estimators=19, max-depth=8, learning_rate=0.01, The mean accuracy=0.764
# Model 241, n_estimators=19, max-depth=8, learning_rate=0.03, The mean accuracy=0.75
# Model 242, n_estimators=19, max-depth=8, learning_rate=0.049999999999999996, The mean accuracy=0.736
# Model 243, n_estimators=19, max-depth=8, learning_rate=0.06999999999999999, The mean accuracy=0.736
# Model 244, n_estimators=19, max-depth=8, learning_rate=0.08999999999999998, The mean accuracy=0.75
# Model 245, n_estimators=19, max-depth=9, learning_rate=0.01, The mean accuracy=0.75
# Model 246, n_estimators=19, max-depth=9, learning_rate=0.03, The mean accuracy=0.736
# Model 247, n_estimators=19, max-depth=9, learning_rate=0.049999999999999996, The mean accuracy=0.75
# Model 248, n_estimators=19, max-depth=9, learning_rate=0.06999999999999999, The mean accuracy=0.75
# Model 249, n_estimators=19, max-depth=9, learning_rate=0.08999999999999998, The mean accuracy=0.736

# %% [markdown]
# ## Best Model

# %%
log[np.argmax(acc)]
# Out:
# 'Model 28, n_estimators=11, max-depth=5, learning_rate=0.06999999999999999, The mean accuracy=0.806'

# %% [markdown]
# # NEURAL NETWORK

# %%
# Prepare the label data
y_train_dv = np.array(pd.get_dummies(y_train))
y_test_dv = np.array(pd.get_dummies(y_test))
X_train = np.array(x_train)
X_test = np.array(x_test)

# %%
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Dense, Activation, Dropout
from keras import optimizers
print('Done')

callbacks = [
    EarlyStopping(monitor='val_loss', min_delta=0.00001, patience=5),
    ModelCheckpoint('model.h5', monitor='val_loss', save_best_only=True, verbose=0)
]


n_classes = 2
epochs = 100
learn_rate = 0.001
batch_size= 256
dropout = 0.1
init_mean = 0.0
init_stdev = 0.05

m = Sequential()
m.add(Dense(15, activation='relu', input_shape=(10,)))
m.add(Dense(30, activation='relu'))
# m.add(Dropout(dropout))
# m.add(Dense(50, activation='relu'))
# m.add(Dense(50, activation='relu'))
# m.add(Dropout(dropout))
# m.add(Dense(30, activation='relu'))
# m.add(Dense(10, activation='relu'))
m.add(Dense(n_classes, activation='softmax'))  # None = linear activation for regression

m.compile(
    optimizer=optimizers.Adam(lr=learn_rate),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print('Starting training....')

history_object = m.fit(X_train, 
          y_train_dv, 
          validation_split=0.1,
          shuffle=True,
          epochs=epochs,
          batch_size=batch_size,
          callbacks=callbacks)

print('Done')
# Out:
# Done
# Starting training....
# Train on 577 samples, validate on 65 samples
# Epoch 1/100
# 577/577 [==============================] - 0s - loss: 4.6918 - acc: 0.3951 - val_loss: 2.9130 - val_acc: 0.5231
# Epoch 2/100
# 577/577 [==============================] - 0s - loss: 4.0340 - acc: 0.3951 - val_loss: 2.3434 - val_acc: 0.5231
# Epoch 3/100
# 577/577 [==============================] - 0s - loss: 3.2396 - acc: 0.3951 - val_loss: 1.7477 - val_acc: 0.5231
# Epoch 4/100
# 577/577 [==============================] - 0s - loss: 2.4276 - acc: 0.3951 - val_loss: 1.2527 - val_acc: 0.4923
# Epoch 5/100
# 577/577 [==============================] - 0s - loss: 1.6968 - acc: 0.3778 - val_loss: 1.1040 - val_acc: 0.4154
# Epoch 6/100
# 577/577 [==============================] - 0s - loss: 1.2095 - acc: 0.3518 - val_loss: 1.3036 - val_acc: 0.3846
# Epoch 7/100
# 577/577 [==============================] - 0s - loss: 1.1623 - acc: 0.3414 - val_loss: 1.5043 - val_acc: 0.4615
# Epoch 8/100
# 577/577 [==============================] - 0s - loss: 1.2211 - acc: 0.5494 - val_loss: 1.4935 - val_acc: 0.5538
# Epoch 9/100
# 577/577 [==============================] - 0s - loss: 1.1196 - acc: 0.5910 - val_loss: 1.3559 - val_acc: 0.5692
# Epoch 10/100
# 577/577 [==============================] - 0s - loss: 0.9850 - acc: 0.6291 - val_loss: 1.1871 - val_acc: 0.5692
# Epoch 11/100
# 577/577 [==============================] - 0s - loss: 0.9378 - acc: 0.6551 - val_loss: 1.0413 - val_acc: 0.5538
# Epoch 12/100
# 577/577 [==============================] - 0s - loss: 0.9274 - acc: 0.6603 - val_loss: 0.9449 - val_acc: 0.5385
# Epoch 13/100
# 577/577 [==============================] - 0s - loss: 0.9312 - acc: 0.6724 - val_loss: 0.8878 - val_acc: 0.5385
# Epoch 14/100
# 577/577 [==============================] - 0s - loss: 0.9311 - acc: 0.6672 - val_loss: 0.8526 - val_acc: 0.5538
# Epoch 15/100
# 577/577 [==============================] - 0s - loss: 0.6032 - acc: 0.6915 - val_loss: 0.6677 - val_acc: 0.6308
# Epoch 39/100
# 577/577 [==============================] - 0s - loss: 0.6017 - acc: 0.6898 - val_loss: 0.6603 - val_acc: 0.6462
# Epoch 40/100
# 577/577 [==============================] - 0s - loss: 0.6036 - acc: 0.6898 - val_loss: 0.6638 - val_acc: 0.6308
# Epoch 41/100
# 577/577 [==============================] - 0s - loss: 0.6000 - acc: 0.6932 - val_loss: 0.6853 - val_acc: 0.6154
# Epoch 42/100
# 577/577 [==============================] - 0s - loss: 0.6029 - acc: 0.6915 - val_loss: 0.6692 - val_acc: 0.6308
# Epoch 43/100
# 577/577 [==============================] - ETA: 0s - loss: 0.6143 - acc: 0.671 - 0s - loss: 0.5964 - acc: 0.6915 - val_loss: 0.6503 - val_acc: 0.6462
# Epoch 44/100
# 577/577 [==============================] - 0s - loss: 0.6038 - acc: 0.6898 - val_loss: 0.6500 - val_acc: 0.6462
# Epoch 45/100
# 577/577 [==============================] - 0s - loss: 0.5966 - acc: 0.6915 - val_loss: 0.6618 - val_acc: 0.6308
# Epoch 46/100
# 577/577 [==============================] - 0s - loss: 0.5932 - acc: 0.6950 - val_loss: 0.6705 - val_acc: 0.6308
# Epoch 47/100
# 577/577 [==============================] - 0s - loss: 0.5927 - acc: 0.7002 - val_loss: 0.6511 - val_acc: 0.6308
# Epoch 48/100
# 577/577 [==============================] - 0s - loss: 0.5958 - acc: 0.6915 - val_loss: 0.6434 - val_acc: 0.6462
# Epoch 49/100
# 577/577 [==============================] - 0s - loss: 0.5942 - acc: 0.6932 - val_loss: 0.6500 - val_acc: 0.6308
# Epoch 50/100
# 577/577 [==============================] - 0s - loss: 0.5877 - acc: 0.6915 - val_loss: 0.6458 - val_acc: 0.6308
# Epoch 51/100
# 577/577 [==============================] - 0s - loss: 0.5873 - acc: 0.6932 - val_loss: 0.6461 - val_acc: 0.6308
# Epoch 52/100
# 577/577 [==============================] - 0s - loss: 0.5851 - acc: 0.6967 - val_loss: 0.6525 - val_acc: 0.6462
# Epoch 53/100
# 577/577 [==============================] - 0s - loss: 0.5859 - acc: 0.7192 - val_loss: 0.6593 - val_acc: 0.6308
# Epoch 54/100
# 577/577 [==============================] - 0s - loss: 0.5903 - acc: 0.7088 - val_loss: 0.6467 - val_acc: 0.6308
# Done

# %%
### print the keys contained in the history object
print(history_object.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history_object.history['loss'])
plt.plot(history_object.history['val_loss'])
plt.title('model categorical crossentropy loss')
plt.ylabel('mean categorical crossentropy loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['val_loss', 'loss', 'acc', 'val_acc'])

# %%
### plot the training and validation loss for each epoch
plt.plot(history_object.history['acc'])
plt.plot(history_object.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('mean accuracy')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()

# %%
col_names = m.metrics_names
values = m.evaluate(x=X_test, y=y_test_dv, batch_size=256)

print(col_names[0], values[0]) 
print(col_names[1], values[1])
# Out:
# 72/72 [==============================] - 0s
# loss 0.579023063183
# acc 0.722222208977
